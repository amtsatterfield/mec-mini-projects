# %% [markdown]
# This exercise will require you to pull some data from the Qunadl API. Qaundl is currently the most widely used aggregator of financial market data.

# %% [markdown]
# As a first step, you will need to register a free account on the http://www.quandl.com website.

# %% [markdown]
# After you register, you will be provided with a unique API key, that you should store:

# %%
# Store the API key as a string - according to PEP8, constants are always named in all upper case
API_KEY = '8gVEZnPh1QMHzGR6PnF-'

# %% [markdown]
# Qaundl has a large number of data sources, but, unfortunately, most of them require a Premium subscription. Still, there are also a good number of free datasets.

# %% [markdown]
# For this mini project, we will focus on equities data from the Frankfurt Stock Exhange (FSE), which is available for free. We'll try and analyze the stock prices of a company called Carl Zeiss Meditec, which manufactures tools for eye examinations, as well as medical lasers for laser eye surgery: https://www.zeiss.com/meditec/int/home.html. The company is listed under the stock ticker AFX_X.

# %% [markdown]
# You can find the detailed Quandl API instructions here: https://docs.quandl.com/docs/time-series

# %% [markdown]
# While there is a dedicated Python package for connecting to the Quandl API, we would prefer that you use the *requests* package, which can be easily downloaded using *pip* or *conda*. You can find the documentation for the package here: http://docs.python-requests.org/en/master/

# %% [markdown]
# Finally, apart from the *requests* package, you are encouraged to not use any third party Python packages, such as *pandas*, and instead focus on what's available in the Python Standard Library (the *collections* module might come in handy: https://pymotw.com/3/collections/).
# Also, since you won't have access to DataFrames, you are encouraged to us Python's native data structures - preferably dictionaries, though some questions can also be answered using lists.
# You can read more on these data structures here: https://docs.python.org/3/tutorial/datastructures.html

# %% [markdown]
# Keep in mind that the JSON responses you will be getting from the API map almost one-to-one to Python's dictionaries. Unfortunately, they can be very nested, so make sure you read up on indexing dictionaries in the documentation provided above.

# %%
# First, import the relevant modules
import requests
import json

# %%
# Now, call the Quandl API and pull out a small sample of the data (only one day) to get a glimpse
# into the JSON structure that will be returned
RESPONSE = requests.get(fr"https://www.quandl.com/api/v3/datasets/XFRA/AGB2/data.json?api_key={API_KEY}")
print(RESPONSE.json())
# Out:
# {'dataset_data': {'limit': None, 'transform': None, 'column_index': None, 'column_names': ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Adjustment Factor', 'Adjustment Type'], 'start_date': '2007-01-02', 'end_date': '2018-11-30', 'frequency': 'daily', 'data': [['2018-11-30', 15.258776, 15.258776, 15.258776, 15.258776, 0.0, None, None], ['2018-11-29', 14.823805, 14.823805, 14.823805, 14.823805, 0.0, None, None], ['2018-11-28', 15.119585, 15.119585, 15.119585, 15.119585, 0.0, None, None], ['2018-11-27', 15.310972, 15.310972, 15.310972, 15.310972, 0.0, None, None], ['2018-11-26', 15.258776, 15.258776, 15.258776, 15.258776, 0.0, None, None], ['2018-11-23', 14.980395, 14.980395, 14.980395, 14.980395, 0.0, None, None], ['2018-11-22', 15.119585, 15.119585, 15.119585, 15.119585, 0.0, None, None], ['2018-11-21', 14.928198, 14.928198, 14.928198, 14.928198, 0.0, None, None], ['2018-11-20', 14.806406, 15.154383, 14.806406, 15.154383, 60.0, None, None], ['2018-11-19', 14.962996, 14.962996, 
# ...

# %%
# Inspect the JSON structure of the object you created, and take note of how nested it is,
# as well as the overall structure

# %% [markdown]
# These are your tasks for this mini project:
#
# 1. Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD).
# 2. Convert the returned JSON object into a Python dictionary.
# 3. Calculate what the highest and lowest opening prices were for the stock in this period.
# 4. What was the largest change in any one day (based on High and Low price)?
# 5. What was the largest change between any two days (based on Closing Price)?
# 6. What was the average daily trading volume during this year?
# 7. (Optional) What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the median.)

# %%
# 1. Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD).

# %%
URL = fr"https://www.quandl.com/api/v3/datasets/XFRA/AGB2/data.json?api_key={API_KEY}"
PARAMS = {'apikey': API_KEY, 'start_date': '2017-01-01', 'end_date': '2017-12-31'}
RESPONSE = requests.get(URL, params=PARAMS)
print(RESPONSE.json())
# Out:
# {'dataset_data': {'limit': None, 'transform': None, 'column_index': None, 'column_names': ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Adjustment Factor', 'Adjustment Type'], 'start_date': '2017-01-01', 'end_date': '2017-12-31', 'frequency': 'daily', 'data': [['2017-12-29', 21.338398, 21.475928, 21.329105, 21.329105, 1240.0, None, None], ['2017-12-28', 21.143461, 21.143461, 21.143461, 21.143461, 0.0, None, None], ['2017-12-27', 21.181663, 21.393534, 21.181663, 21.393534, 1616.0, None, None], ['2017-12-26', 21.26096, 21.26096, 21.26096, 21.26096, 0.0, None, None], ['2017-12-25', 21.26096, 21.26096, 21.26096, 21.26096, 0.0, None, None], ['2017-12-22', 21.14821, 21.368547, 21.14821, 21.26096, 716.0, None, None], ['2017-12-21', 20.867988, 20.867988, 20.867988, 20.867988, 0.0, None, None], ['2017-12-20', 21.006137, 21.083782, 21.006137, 21.083782, 600.0, None, None], ['2017-12-19', 21.069946, 21.184141, 20.98239, 21.184141, 560.0, None, None], ['2017-12-18', 21.096378, 21.362559, 2
# ...

# %%
# 2. Convert the returned JSON object into a Python dictionary.
type(RESPONSE.json())
# Out:
# dict

# %%
# 3. Calculate what the highest and lowest opening prices were for the stock in this period.

# %%
DCT = RESPONSE.json()
print(DCT.get('dataset_data').get('column_names'))
# Out:
# ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Adjustment Factor', 'Adjustment Type']

# %%
_index = (DCT.get('dataset_data').get('column_names'))
_high = _index.index('High')
_low = _index.index('Low')
_high, _low
# Out:
# (2, 3)

# %%
_data = DCT.get('dataset_data').get('data')
_highs = []
_lows = []
for _obs in _data:
    _highs.append(_obs[2])
    _lows.append(_obs[3])
print(f'Highest price: {max(_highs)}\nLowest price: {min(_lows)}')
# Out:
# Highest price: 25.23559
# Lowest price: 18.112429

# %%
# 4. What was the largest change in any one day (based on High and Low price)?

# %%
_largest_change = []
for _obs in _data:
    _largest_change.append(_obs[2] - _obs[3])
print(f'Largest change: {round(max(_largest_change), 2)} dollars')
# Out:
# Largest change: 2.26 dollars

# %%
# 5. What was the largest change between any two days (based on Closing Price)?

# %%
_index = (DCT.get('dataset_data').get('column_names'))
_close = _index.index('Close')
_close
# Out:
# 4

# %%
_close_gap = []
for _i, _obs in enumerate(_data):
    _gap = abs(_obs[4] - _data[_i - 1][4])
    _close_gap.append(_gap)
print(f'Largest gap in Close between two days: {round(max(_close_gap), 2)} dollars')
# Out:
# Largest gap in Close between two days: 1.7 dollars

# %%
# 6. What was the average daily trading volume during this year?

# %%
_close = _index.index('Volume')
_close
# Out:
# 5

# %%
_avg_vol = []
for _obs in _data:
    _avg_vol.append(_obs[5])
print(f'Average Volume: {sum(_avg_vol)/len(_avg_vol)}')
# Out:
# Average Volume: 525.4307692307692
